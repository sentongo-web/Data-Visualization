# %% [markdown]
# #### Data Viz: Assignment 2 of 4
#
# RUBRICS
# - Correct values and approach.
# - Number of additional data wrangling techniques demonstrated.
# - Any added comment on the exercise.
# - Provide a single Jupyter Notebook file for your solution.

# %%
#importing the necessary libraries
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##### 1.	Download 5 datasets of your choice from https://www.fao.org/faostat/en/#data (the dataset chosen should have a date value) and combine them into a single file and store the dataframe of the data as fao for the rest of the exercises:

# %% [markdown]
# ##### The downloaded dataset focuses on Annual population, while 5 countries have been chosen and dataset link is https://www.fao.org/faostat/en/#data/OA

# %%
# Reading all the datasets downloaded.
Nigeria = pd.read_csv('Nigeria.csv')
Portugal = pd.read_csv('Portugal.csv')
USA = pd.read_csv('USA.csv')
UK = pd.read_csv('UK.csv')
India = pd.read_csv('India.csv')

# %% [markdown]
# ##### To visualize the Nigeria dataset

# %%
Nigeria.head(2)
# Out:
#   Domain Code             Domain  Area Code (M49)     Area  Element Code  \
# 0          OA  Annual population              566  Nigeria           511
# 1          OA  Annual population              566  Nigeria           511
#
#                          Element  Item Code                       Item  \
# 0  Total Population - Both sexes       3010  Population - Est. & Proj.
# 1  Total Population - Both sexes       3010  Population - Est. & Proj.
#
#    Year Code  Year     Unit      Value Flag  \
# 0       1950  1950  1000 No  37189.369    X
# 1       1951  1951  1000 No  37903.171    X
#
#                           Flag Description  Note
# 0  Figure from international organizations   NaN
# 1  Figure from international organizations   NaN

# %% [markdown]
# ##### To view the top 2 records of the Portugal dataset

# %%
Portugal.head(2)
# Out:
#   Domain Code             Domain  Area Code (M49)      Area  Element Code  \
# 0          OA  Annual population              620  Portugal           511
# 1          OA  Annual population              620  Portugal           511
#
#                          Element  Item Code                       Item  \
# 0  Total Population - Both sexes       3010  Population - Est. & Proj.
# 1  Total Population - Both sexes       3010  Population - Est. & Proj.
#
#    Year Code  Year     Unit     Value Flag  \
# 0       1950  1950  1000 No  8416.952    X
# 1       1951  1951  1000 No  8472.644    X
#
#                           Flag Description  Note
# 0  Figure from international organizations   NaN
# 1  Figure from international organizations   NaN

# %% [markdown]
# ##### To view the top records of the UK annual population dataset

# %%
UK.head(2)
# Out:
#   Domain Code             Domain  Area Code (M49)  \
# 0          OA  Annual population              826
# 1          OA  Annual population              826
#
#                                                 Area  Element Code  \
# 0  United Kingdom of Great Britain and Northern I...           511
# 1  United Kingdom of Great Britain and Northern I...           511
#
#                          Element  Item Code                       Item  \
# 0  Total Population - Both sexes       3010  Population - Est. & Proj.
# 1  Total Population - Both sexes       3010  Population - Est. & Proj.
#
#    Year Code  Year     Unit      Value Flag  \
# 0       1950  1950  1000 No  50055.065    X
# 1       1951  1951  1000 No  50271.904    X
#
#                           Flag Description  Note
# 0  Figure from international organizations   NaN
# 1  Figure from international organizations   NaN

# %% [markdown]
# ##### To view the top records of the USA polulation dataset

# %%
USA.head(2)
# Out:
#   Domain Code             Domain  Area Code (M49)                      Area  \
# 0          OA  Annual population              840  United States of America
# 1          OA  Annual population              840  United States of America
#
#    Element Code                        Element  Item Code  \
# 0           511  Total Population - Both sexes       3010
# 1           511  Total Population - Both sexes       3010
#
#                         Item  Year Code  Year     Unit       Value Flag  \
# 0  Population - Est. & Proj.       1950  1950  1000 No  148281.550    X
# 1  Population - Est. & Proj.       1951  1951  1000 No  150598.453    X
#
#                           Flag Description  Note
# 0  Figure from international organizations   NaN
# 1  Figure from international organizations   NaN

# %% [markdown]
# ##### To view the top records of the India dataset

# %%
India.head(2)
# Out:
#   Domain Code             Domain  Area Code (M49)   Area  Element Code  \
# 0          OA  Annual population              356  India           511
# 1          OA  Annual population              356  India           511
#
#                          Element  Item Code                       Item  \
# 0  Total Population - Both sexes       3010  Population - Est. & Proj.
# 1  Total Population - Both sexes       3010  Population - Est. & Proj.
#
#    Year Code  Year     Unit      Value Flag  \
# 0       1950  1950  1000 No  357021.10    X
# 1       1951  1951  1000 No  364922.36    X
#
#                           Flag Description  Note
# 0  Figure from international organizations   NaN
# 1  Figure from international organizations   NaN

# %% [markdown]
# ##### To visualise the top records of the Nigeria population dataset

# %%
Nigeria.head(2)
# Out:
#   Domain Code             Domain  Area Code (M49)     Area  Element Code  \
# 0          OA  Annual population              566  Nigeria           511
# 1          OA  Annual population              566  Nigeria           511
#
#                          Element  Item Code                       Item  \
# 0  Total Population - Both sexes       3010  Population - Est. & Proj.
# 1  Total Population - Both sexes       3010  Population - Est. & Proj.
#
#    Year Code  Year     Unit      Value Flag  \
# 0       1950  1950  1000 No  37189.369    X
# 1       1951  1951  1000 No  37903.171    X
#
#                           Flag Description  Note
# 0  Figure from international organizations   NaN
# 1  Figure from international organizations   NaN

# %% [markdown]
# ##### A.	Read in each file in your Jupyter Notebook file.
# ##### B.	Add a column to each dataframe, called “newColumn”, with data of your choice that could be a manipulation of any other column.
#
# ##### C.	Append all the dataframes from (A) together into a single dataframe.

# %% [markdown]
# ##### Below i create a list that contains all names of my datasets and then i store them,
# ##### I load the datasets into the list and then i add a newcolumn, which column is to have values of cumulative population and Save the result in a CSV file called fao.csv.

# %%
# List of dataset filenames
dataset_files = ["Nigeria.csv", "India.csv", "Uk.csv", "USA.csv", "Portugal.csv"]

# List to store loaded datasets
datasets = []

# Load each dataset into the list and add 'newColumn', we are to use a loop to check if the field Value 
# exists in the dataset and then it loads data
for file in dataset_files:
    # just assuming if all datasets have a header row
    fao = pd.read_csv(file)
    
    # Checking if 'Value' column exists before adding 'newColumn' then storing values of cummulative population there
    if 'Value' in fao.columns:
        fao['newColumn'] = fao['Value'].cumsum()
    else:
        print(f"Warning: 'Value' column not found in {file} dataset.")
    
    datasets.append(fao)

# Concatenating all dataframes into a single dataframe named fao
fao = pd.concat(datasets, ignore_index=True)

# Saving the concatenated dataframe to a CSV file named 'fao.csv'
fao.to_csv("fao.csv", index=False)

# Displaying the head of the modified dataframe fao
print("\nHead of the 'fao' dataset with 'newColumn' (Cumulative Population):\n")
print(fao.head().to_string(index=False))
# Out:
# Head of the 'fao' dataset with 'newColumn' (Cumulative Population):
#
# Domain Code            Domain  Area Code (M49)    Area  Element Code                       Element  Item Code                      Item  Year Code  Year    Unit     Value Flag                        Flag Description  Note  newColumn
#          OA Annual population              566 Nigeria           511 Total Population - Both sexes       3010 Population - Est. & Proj.       1950  1950 1000 No 37189.369    X Figure from international organizations   NaN  37189.369
#          OA Annual population              566 Nigeria           511 Total Population - Both sexes       3010 Population - Est. & Proj.       1951  1951 1000 No 37903.171    X Figure from international organizations   NaN  75092.540
# ...

# %% [markdown]
# ##### I visualise the head of the created dataframe fao, just to confirm if the newColumn has been created and added there. The new column is to store the values of my choice and my choice is CUMMULATIVE POPULATION

# %%
fao.head()
# Out:
#   Domain Code             Domain  Area Code (M49)     Area  Element Code  \
# 0          OA  Annual population              566  Nigeria           511
# 1          OA  Annual population              566  Nigeria           511
# 2          OA  Annual population              566  Nigeria           511
# 3          OA  Annual population              566  Nigeria           511
# 4          OA  Annual population              566  Nigeria           511
#
#                          Element  Item Code                       Item  \
# 0  Total Population - Both sexes       3010  Population - Est. & Proj.
# 1  Total Population - Both sexes       3010  Population - Est. & Proj.
# 2  Total Population - Both sexes       3010  Population - Est. & Proj.
# 3  Total Population - Both sexes       3010  Population - Est. & Proj.
# 4  Total Population - Both sexes       3010  Population - Est. & Proj.
#
#    Year Code  Year     Unit      Value Flag  \
# 0       1950  1950  1000 No  37189.369    X
# ...

# %% [markdown]
# ##### 2.	With fao, use type conversion to cast the values of the year column into datetimes and, sort by date and value.

# %% [markdown]
# ##### A new sorted dataframe is later created

# %%
# List of dataset filenames
dataset_files = ["Nigeria.csv", "India.csv", "Uk.csv", "USA.csv", "Portugal.csv"]

# List to store loaded datasets
datasets = []

# Load each dataset into the list and add 'newColumn'
for file in dataset_files:
    # Assuming all datasets have a header row
    fao = pd.read_csv(file)
    
    # Checking if 'Value' column exists before adding 'newColumn'
    if 'Value' in fao.columns:
        fao['newColumn'] = fao['Value'].cumsum()
    else:
        print(f"Warning: 'Value' column not found in {file} dataset.")
    
    datasets.append(fao)

# Concatenating all dataframes into a single dataframe
fao = pd.concat(datasets, ignore_index=True)

# Converting the 'Year' column to datetime format
fao['Year'] = pd.to_datetime(fao['Year'], format='%Y')

# Sorting the dataframe by 'Year' and 'Value'
fao = fao.sort_values(by=['Year', 'Value'])

# Saving the sorted dataframe to a CSV file named 'fao_sorted.csv'
fao.to_csv("fao_sorted.csv", index=False)

# Displaying the head of the sorted dataframe
print("\nHead of the sorted 'fao' dataset by 'Year' and 'Value':\n")
print(fao.head().to_string(index=False))
# Out:
# Head of the sorted 'fao' dataset by 'Year' and 'Value':
#
# Domain Code            Domain  Area Code (M49)                                                 Area  Element Code                       Element  Item Code                      Item  Year Code       Year    Unit      Value Flag                        Flag Description  Note  newColumn
#          OA Annual population              620                                             Portugal           511 Total Population - Both sexes       3010 Population - Est. & Proj.       1950 1950-01-01 1000 No   8416.952    X Figure from international organizations   NaN   8416.952
#          OA Annual population              566                                              Nigeria           511 Total Population - Both sexes       3010 Population - Est. & Proj.       1950 1950-01-01 1000 No  37189.369    X Figure from international organizations   NaN  37189.369
# ...

# %% [markdown]
# ##### 3.	Find the seven rows in fao with the lowest value for a column of your choice.
# 4.	Right now, the data is somewhere between long and wide format. Use melt() to make it completely long format.

# %%
# Load the 'fao' dataset
fao = pd.read_csv("fao_sorted.csv")

# Find the seven rows with the lowest values in 'Value'
lowest_rows = fao.nsmallest(7, 'Value')

# Display the seven rows with the lowest values
print("\nSeven rows with the lowest values in 'Value' column:\n")
print(lowest_rows.to_string(index=False))
# Out:
# Seven rows with the lowest values in 'Value' column:
#
# Domain Code            Domain  Area Code (M49)     Area  Element Code                       Element  Item Code                      Item  Year Code       Year    Unit    Value Flag                        Flag Description  Note  newColumn
#          OA Annual population              620 Portugal           511 Total Population - Both sexes       3010 Population - Est. & Proj.       1950 1950-01-01 1000 No 8416.952    X Figure from international organizations   NaN   8416.952
#          OA Annual population              620 Portugal           511 Total Population - Both sexes       3010 Population - Est. & Proj.       1951 1951-01-01 1000 No 8472.644    X Figure from international organizations   NaN  16889.596
# ...

# %%
# Loading the 'fao' dataset
fao = pd.read_csv("fao_sorted.csv")

# Melting the dataframe to completely long format
fao_long = pd.melt(fao, id_vars=['Area', 'Year'], value_vars=['Domain Code', 'Domain', 'Area Code (M49)', 'Element Code', 'Element', 'Item Code', 'Item', 'Unit', 'Value', 'Flag', 'Flag Description', 'Note', 'newColumn'], var_name='Variable', value_name='Variable Value')

# Saving the melted dataframe to a CSV file named 'fao_long.csv'
fao_long.to_csv("fao_long.csv", index=False)

# Displaying the head of the melted dataframe
print("\nHead of the melted 'fao_long' dataset:\n")
print(fao_long.head().to_string(index=False))
# Out:
# Head of the melted 'fao_long' dataset:
#
#                                                 Area       Year    Variable Variable Value
#                                             Portugal 1950-01-01 Domain Code             OA
#                                              Nigeria 1950-01-01 Domain Code             OA
# United Kingdom of Great Britain and Northern Ireland 1950-01-01 Domain Code             OA
#                             United States of America 1950-01-01 Domain Code             OA
#                                                India 1950-01-01 Domain Code             OA

# %% [markdown]
# ##### 6.	Employ any other data wrangling technique in your solution (label each technique as a – z)

# %% [markdown]
# ### DATA WRANGLING TECHNIQUES

# %% [markdown]
# ##### Technique A: Handling Missing Values

# %%
# Checking for missing values in the dataset
missing_values = fao.isnull().sum()

# Printing the number of missing values for each column
print("\nNumber of missing values for each column:")
print(missing_values)

# Imputing missing values in 'Value' column with mean
fao['Value'].fillna(fao['Value'].mean(), inplace=True)

# Displaying the modified dataframe after handling missing values
print("\nHead of the modified 'fao' dataset after handling missing values:")
print(fao.head())
# Out:
# Number of missing values for each column:
# Domain Code           0
# Domain                0
# Area Code (M49)       0
# Area                  0
# Element Code          0
# Element               0
# Item Code             0
# Item                  0
# Year Code             0
# Year                  0
# Unit                  0
# Value                 0
# Flag                  0
# Flag Description      0
# Note                360
# newColumn             0
# dtype: int64
#
# Head of the modified 'fao' dataset after handling missing values:
#   Domain Code             Domain  Area Code (M49)  \
# 0          OA  Annual population              620
# 1          OA  Annual population              566
# 2          OA  Annual population              826
# 3          OA  Annual population              840
# 4          OA  Annual population              356
#
#                                                 Area  Element Code  \
# ...

# %% [markdown]
# ##### Technique B: Handling Outliers

# %%
import pandas as pd
import numpy as np

# Loading the 'fao' dataset
fao = pd.read_csv("fao_sorted.csv")

# Identifying and handle outliers using winsorization
def winsorize(series, lower_limit=0.05, upper_limit=0.95):
    lower_bound = series.quantile(lower_limit)
    upper_bound = series.quantile(upper_limit)
    return np.clip(series, lower_bound, upper_bound)

# Applying winsorization to the 'Value' column
fao['Value'] = winsorize(fao['Value'])

# Displaying summary statistics after handling outliers
print("\nSummary Statistics after handling outliers:")
print(fao.describe())
# Out:
# Summary Statistics after handling outliers:
#        Area Code (M49)  Element Code  Item Code   Year Code         Value  \
# count       360.000000         360.0      360.0   360.00000  3.600000e+02
# mean        641.600000         511.0     3010.0  1985.50000  2.393186e+05
# std         179.757608           0.0        0.0    20.81153  3.131681e+05
# min         356.000000         511.0     3010.0  1950.00000  8.896193e+03
# 25%         566.000000         511.0     3010.0  1967.75000  5.043159e+04
# 50%         620.000000         511.0     3010.0  1985.50000  8.469472e+04
# 75%         826.000000         511.0     3010.0  2003.25000  2.918193e+05
# max         840.000000         511.0     3010.0  2021.00000  1.118358e+06
#
#        Note     newColumn
# count   0.0  3.600000e+02
# mean    NaN  7.209550e+06
# std     NaN  1.181020e+07
# min     NaN  8.416952e+03
# 25%     NaN  5.923135e+05
# 50%     NaN  2.534519e+06
# 75%     NaN  7.332772e+06
# max     NaN  5.973390e+07

# %% [markdown]
# ##### Technique C: Data Normalization or Standardization

# %%
from sklearn.preprocessing import MinMaxScaler
# Normalize 'Value' column using Min-Max scaling
scaler = MinMaxScaler()
fao['Value_normalized'] = scaler.fit_transform(fao[['Value']])

# Display the modified dataframe with normalized values
print("\nHead of the modified 'fao' dataset with normalized values:")
print(fao.head())
# Out:
# Head of the modified 'fao' dataset with normalized values:
#   Domain Code             Domain  Area Code (M49)  \
# 0          OA  Annual population              620
# 1          OA  Annual population              566
# 2          OA  Annual population              826
# 3          OA  Annual population              840
# 4          OA  Annual population              356
#
#                                                 Area  Element Code  \
# 0                                           Portugal           511
# 1                                            Nigeria           511
# 2  United Kingdom of Great Britain and Northern I...           511
# 3                           United States of America           511
# 4                                              India           511
#
#                          Element  Item Code                       Item  \
# 0  Total Population - Both sexes       3010  Population - Est. & Proj.
# ...

# %%
fao.head()
# Out:
#   Domain Code             Domain  Area Code (M49)  \
# 0          OA  Annual population              620
# 1          OA  Annual population              566
# 2          OA  Annual population              826
# 3          OA  Annual population              840
# 4          OA  Annual population              356
#
#                                                 Area  Element Code  \
# 0                                           Portugal           511
# 1                                            Nigeria           511
# 2  United Kingdom of Great Britain and Northern I...           511
# 3                           United States of America           511
# 4                                              India           511
#
#                          Element  Item Code                       Item  \
# 0  Total Population - Both sexes       3010  Population - Est. & Proj.
# 1  Total Population - Both sexes       3010  Population - Est. & Proj.
# ...

# %% [markdown]
# ##### Technique D: Handling Duplicate Data

# %%
# Check for and handle duplicate entries
duplicates_count = fao.duplicated().sum()

# Print the number of duplicate entries
print("\nNumber of duplicate entries:", duplicates_count)

# Drop duplicate rows
fao_no_duplicates = fao.drop_duplicates()

# Display the modified dataframe without duplicate entries
print("\nHead of the modified 'fao' dataset without duplicates:")
print(fao_no_duplicates.head())
# Out:
# Number of duplicate entries: 0
#
# Head of the modified 'fao' dataset without duplicates:
#   Domain Code             Domain  Area Code (M49)  \
# 0          OA  Annual population              620
# 1          OA  Annual population              566
# 2          OA  Annual population              826
# 3          OA  Annual population              840
# 4          OA  Annual population              356
#
#                                                 Area  Element Code  \
# 0                                           Portugal           511
# 1                                            Nigeria           511
# 2  United Kingdom of Great Britain and Northern I...           511
# 3                           United States of America           511
# 4                                              India           511
#
#                          Element  Item Code                       Item  \
# 0  Total Population - Both sexes       3010  Population - Est. & Proj.
# ...
